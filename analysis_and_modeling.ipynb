# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import fpl_functions as fpl
pd.options.mode.chained_assignment = None
sns.set_theme()

# %%
'''
TODO

- add FPL built in ratings for teams done
- prepare data for ML
    - encode player names? maybe not needed
    - add newly promoted boolean
- explore points correlation between players? Is it a better idea to get uncorrelated players, or focus in on correlated sources of points
'''
# Out:
# '\nTODO\n\n- add FPL built in ratings for teams done\n- prepare data for ML\n    - encode player names? maybe not needed\n    - add newly promoted boolean\n- explore points correlation between players? Is it a better idea to get uncorrelated players, or focus in on correlated sources of points\n'

# %%
players_url = "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2023-24/gws/merged_gw.csv"
fixtures_url = "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2023-24/fixtures.csv"
teams_url = "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2023-24/teams.csv"

players = pd.read_csv(players_url)
fixtures = pd.read_csv(fixtures_url)
teams = pd.read_csv(teams_url)

# %%
players.head()
# Out:
#                      name position           team   xP  assists  bonus  bps  \
# 0             Femi Seriki      DEF  Sheffield Utd  0.5        0      0    0
# 1        Jack Hinshelwood      MID       Brighton  1.5        0      0    0
# 2            Jadon Sancho      MID        Man Utd  3.0        0      0    4
# 3  Rhys Norrington-Davies      DEF  Sheffield Utd  0.1        0      0    0
# 4           Vitaly Janelt      MID      Brentford  2.1        0      0    6
#
#    clean_sheets  creativity  element  ...  team_h_score  threat  total_points  \
# 0             0         0.0      653  ...             0     0.0             0
# 1             0         0.0      621  ...             4     0.0             0
# 2             0        11.3      397  ...             1     8.0             1
# 3             0         0.0      487  ...             0     0.0             0
# 4             0        11.5      105  ...             2    17.0             2
#
#    transfers_balance  transfers_in  transfers_out  value  was_home  \
# 0                  0             0              0     40      True
# 1                  0             0              0     45      True
# 2                  0             0              0     70      True
# 3                  0             0              0     40      True
# 4                  0             0              0     55      True
#
#    yellow_cards GW
# 0             0  1
# 1             0  1
# 2             0  1
# 3             0  1
# 4             0  1
#
# [5 rows x 41 columns]

# %%
players.columns
# Out:
# Index(['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals',
#        'expected_goals_conceded', 'fixture', 'goals_conceded', 'goals_scored',
#        'ict_index', 'influence', 'kickoff_time', 'minutes', 'opponent_team',
#        'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards',
#        'round', 'saves', 'selected', 'starts', 'team_a_score', 'team_h_score',
#        'threat', 'total_points', 'transfers_balance', 'transfers_in',
#        'transfers_out', 'value', 'was_home', 'yellow_cards', 'GW'],
#       dtype='object')

# %%
teams.head().T
# Out:
#                              0            1            2          3         4
# code                         3            7           91         94        36
# draw                         0            0            0          0         0
# form                       NaN          NaN          NaN        NaN       NaN
# id                           1            2            3          4         5
# loss                         0            0            0          0         0
# name                   Arsenal  Aston Villa  Bournemouth  Brentford  Brighton
# played                       0            0            0          0         0
# points                       0            0            0          0         0
# position                     0            0            0          0         0
# short_name                 ARS          AVL          BOU        BRE       BHA
# strength                     5            4            3          3         3
# team_division              NaN          NaN          NaN        NaN       NaN
# unavailable              False        False        False      False     False
# win                          0            0            0          0         0
# strength_overall_home     1350         1160         1100       1100      1100
# strength_overall_away     1365         1285         1100       1100      1210
# strength_attack_home      1370         1140         1055       1110      1070
# strength_attack_away      1370         1220         1130       1055      1180
# strength_defence_home     1330         1180         1145       1090      1135
# strength_defence_away     1360         1350         1075       1150      1240
# pulse_id                     1            2          127        130       131

# %%
teams['name'].values
# Out:
# array(['Arsenal', 'Aston Villa', 'Bournemouth', 'Brentford', 'Brighton',
#        'Burnley', 'Chelsea', 'Crystal Palace', 'Everton', 'Fulham',
#        'Liverpool', 'Luton', 'Man City', 'Man Utd', 'Newcastle',
#        "Nott'm Forest", 'Sheffield Utd', 'Spurs', 'West Ham', 'Wolves'],
#       dtype=object)

# %%
teams['overall_strength'] = teams['strength_overall_home'] + teams['strength_overall_away']
list(teams.sort_values(by='overall_strength', ascending=False)['name'])
# Out:
# ['Man City',
#  'Arsenal',
#  'Liverpool',
#  'Aston Villa',
#  'Spurs',
#  'Newcastle',
#  'Man Utd',
#  'Chelsea',
#  'Brighton',
#  'West Ham',
#  'Fulham',
#  'Brentford',
#  'Wolves',
#  'Bournemouth',
#  'Everton',
#  'Crystal Palace',
#  "Nott'm Forest",
#  'Luton',
#  'Burnley',
#  'Sheffield Utd']

# %%
#make strength tier for teams
teams.loc[teams['name'].isin(['Man City','Arsenal','Liverpool','Aston Villa']), 'tier'] = 4
teams.loc[teams['name'].isin(['Spurs','Newcastle','Man Utd','Chelsea']), 'tier'] = 3
teams.loc[teams['name'].isin(['Brighton','West Ham','Fulham','Brentford']), 'tier'] = 2
teams.loc[teams['name'].isin(['Wolves','Bournemouth','Everton','Crystal Palace']), 'tier'] = 1
teams.loc[teams['name'].isin(["Nott'm Forest",'Luton','Burnley','Sheffield Utd']), 'tier'] = 0

# %%
fixtures.drop(['id', 'code', 'finished', 'finished_provisional', 'minutes', 'provisional_start_time', 'started', 'stats', 'pulse_id'], axis=1, inplace=True)
fixtures.rename(columns={'event': 'Gameweek'}, inplace=True)
fixtures['kickoff_date'] = fixtures['kickoff_time'].apply(lambda x: x.split('T')[0])
fixtures['kickoff_time'] = fixtures['kickoff_time'].apply(lambda x: x.split('T')[1].replace('Z', ''))
fixtures = fixtures[['Gameweek', 'kickoff_date', 'kickoff_time', 'team_a', 'team_a_score', 'team_h', 'team_h_score', 'team_h_difficulty', 'team_a_difficulty']]
fixtures['team_a'] = fixtures['team_a'].map(teams.set_index('id').name)
fixtures['team_h'] = fixtures['team_h'].map(teams.set_index('id').name)
fixtures.head()
# Out:
#    Gameweek kickoff_date kickoff_time         team_a  team_a_score  \
# 0         1   2023-08-11     19:00:00       Man City             3
# 1         1   2023-08-12     12:00:00  Nott'm Forest             1
# 2         1   2023-08-12     14:00:00       West Ham             1
# 3         1   2023-08-12     14:00:00          Luton             1
# 4         1   2023-08-12     14:00:00         Fulham             1
#
#         team_h  team_h_score  team_h_difficulty  team_a_difficulty
# 0      Burnley             0                  5                  2
# 1      Arsenal             2                  2                  5
# 2  Bournemouth             1                  2                  2
# 3     Brighton             4                  2                  3
# 4      Everton             0                  2                  2

# %%
#before removing players from dataset who don't meet minutes requirements, create DF for expected goals conceded per team, by GW
xgc = pd.DataFrame((players.loc[players['position'] == 'GK'].groupby(['team', 'GW'])['expected_goals_conceded'].sum()).cumsum()).reset_index()
#xgc['expected_goals_conceded'] = np.round(xgc['expected_goals_conceded']/xgc['GW'], 2)

# %%
player_minutes = players.groupby('name')['minutes'].sum()
player_minutes.describe()
# Out:
# count     869.000000
# mean      861.484465
# std      1036.526341
# min         0.000000
# 25%         0.000000
# 50%       338.000000
# 75%      1585.000000
# max      3420.000000
# Name: minutes, dtype: float64

# %%
no_min = list(player_minutes[player_minutes == 0].index)
players.drop(players[players['name'].isin(no_min)].index, inplace=True)
player_minutes = players.groupby('name')['minutes'].sum()
below_med = list(player_minutes[player_minutes <= player_minutes.mean()].index)
players.drop(players[players['name'].isin(below_med)].index, inplace=True)

# %%
player_minutes = players.groupby('name')['minutes'].sum()
player_minutes.describe()
# Out:
# count     267.000000
# mean     2250.865169
# std       610.802532
# min      1310.000000
# 25%      1703.000000
# 50%      2208.000000
# 75%      2778.000000
# max      3420.000000
# Name: minutes, dtype: float64

# %%
players.drop('round', axis=1, inplace=True)
players = players.merge(teams[['name', 'tier']].rename(columns={'name': 'team', 'tier': 'team_tier'}), how='left', on='team')
players['opponent_team'] = players['opponent_team'].map(teams.set_index('id').name)
players = players.merge(xgc.rename(columns={'team': 'opponent_team', 'expected_goals_conceded': 'opp_xgc'}), how='left', left_on=['opponent_team', 'GW'], right_on=['opponent_team', 'GW'])
#players['FDR'] = players.apply(lambda x: fpl.single_fixture_by_team(fixtures, x['team'], x['GW']).loc[fpl.single_fixture_by_team(fixtures, x['team'], x['GW'])['opponent'] == x['opponent_team']]['FDR'].iloc[-1], axis=1)
p1 = players.loc[players['was_home'] == True].merge(teams[['name', 'strength_attack_away', 
                                                           'strength_defence_away', 'tier']].rename(columns={'name': 'opponent_team', 
                                                           'strength_attack_away': 'opponent_attack_strength',
                                                           'strength_defence_away': 'opponent_defence_strength',
                                                           'tier': 'opponent_tier'}), how='left', on='opponent_team')
p2 = players.loc[players['was_home'] == False].merge(teams[['name', 'strength_attack_home',
                                                            'strength_defence_home']].rename(columns={'name': 'opponent_team', 
                                                            'strength_attack_home': 'opponent_attack_strength',
                                                            'strength_defence_home': 'opponent_defence_strength',
                                                            'tier': 'opponent_tier'}), how='left', on='opponent_team')
players2 = pd.concat([p1, p2])

# %%
players2.columns
# Out:
# Index(['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals',
#        'expected_goals_conceded', 'fixture', 'goals_conceded', 'goals_scored',
#        'ict_index', 'influence', 'kickoff_time', 'minutes', 'opponent_team',
#        'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards',
#        'saves', 'selected', 'starts', 'team_a_score', 'team_h_score', 'threat',
#        'total_points', 'transfers_balance', 'transfers_in', 'transfers_out',
#        'value', 'was_home', 'yellow_cards', 'GW', 'team_tier', 'opp_xgc',
#        'opponent_attack_strength', 'opponent_defence_strength',
#        'opponent_tier'],
#       dtype='object')

# %%
players_slim = players2.drop(['xP', 'creativity', 'element', 'fixture', 'ict_index', 'influence', 'selected', 'threat', 'transfers_balance', 
                             'transfers_in', 'transfers_out', 'team_a_score', 'team_h_score'], axis=1)

# %%
players_slim['goal_involvements'] = players_slim['goals_scored'] + players_slim['assists']
players_slim['value'] = players_slim['value']/10

#boolean for whether the opponents team is a newly promoted side
players_slim['promoted'] = players_slim['opponent_team'].apply(lambda x: 1 if x in ['Luton, Sheffield Utd', 'Burnley'] else 0)

#create expected goals and goal involvements vs actual goals and goal involvements columns
players_slim['g_vs_xg'] = players_slim['goals_scored'] - players_slim['expected_goals']
players_slim['gi_vs_xgi'] = players_slim['goal_involvements'] - players_slim['expected_goal_involvements']
players_slim['gc_vs_xgc'] = players_slim['goals_conceded'] - players_slim['expected_goals_conceded']

#weighted columns
players_slim['weighted_points'] = players_slim['total_points']*(players_slim['opponent_defence_strength'] + players_slim['opponent_defence_strength'])/2
players_slim['weighted_xgi'] = players_slim['expected_goal_involvements']*players_slim['opponent_defence_strength']

# %%
players_slim.columns
# Out:
# Index(['name', 'position', 'team', 'assists', 'bonus', 'bps', 'clean_sheets',
#        'expected_assists', 'expected_goal_involvements', 'expected_goals',
#        'expected_goals_conceded', 'goals_conceded', 'goals_scored',
#        'kickoff_time', 'minutes', 'opponent_team', 'own_goals',
#        'penalties_missed', 'penalties_saved', 'red_cards', 'saves', 'starts',
#        'total_points', 'value', 'was_home', 'yellow_cards', 'GW', 'team_tier',
#        'opp_xgc', 'opponent_attack_strength', 'opponent_defence_strength',
#        'opponent_tier', 'goal_involvements', 'promoted', 'g_vs_xg',
#        'gi_vs_xgi', 'gc_vs_xgc', 'weighted_points', 'weighted_xgi'],
#       dtype='object')

# %%
# predict next few weeks, rather than single week

data_col = ['assists', 'bonus', 'bps', 'clean_sheets', 'expected_assists', 'expected_goal_involvements', 'expected_goals', 
               'expected_goals_conceded', 'goals_conceded', 'goals_scored', 'minutes', 'own_goals','penalties_missed', 'penalties_saved', 
               'red_cards', 'saves', 'starts', 'total_points', 'was_home', 'yellow_cards', 'opp_xgc', 'opponent_attack_strength', 'opponent_defence_strength',
               'goal_involvements', 'promoted', 'g_vs_xg', 'gi_vs_xgi', 'gc_vs_xgc', 'weighted_points', 'weighted_xgi']

d1 = dict.fromkeys(data_col, 'mean')
gw = 6
full_data = pd.DataFrame()
while gw <= 33:
    temp = players_slim.loc[players_slim['GW'].isin(range(gw-5, gw))]
    prev_weeks = temp.groupby('name').agg({'position': 'first', 'team': 'first', 'team_tier': 'first', **d1, 'value': 'first', 'total_points':['mean', 'sum', 'std']}).round(2)
    prev_weeks.rename(columns={'total_points': 'last_weeks_points'}, inplace=True)
    prev_weeks['GW'] = gw
    p_cols = ['position', 'team', 'team_tier', 'assists', 'bonus', 'bps', 'clean_sheets',
       'expected_assists', 'expected_goal_involvements', 'expected_goals',
       'expected_goals_conceded', 'goals_conceded', 'goals_scored', 'minutes',
       'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards',
       'saves', 'starts', 'last_week_points_mean', 'last_week_points_sum',
       'last_week_points_std', 'was_home', 'yellow_cards', 'opp_xgc', 'opponent_attack_strength', 
       'opponent_defense_strength', 'goal_involvements', 'promoted',
       'g_vs_xg', 'gi_vs_xgi', 'gc_vs_xgc', 'weighted_points', 'weighted_xgi',
       'value', 'GW']
    prev_weeks.set_axis(p_cols, axis=1, inplace=True)
    prev_weeks.reset_index(inplace=True)
    temp2 = players_slim.loc[players_slim['GW'].isin(range(gw, gw+5))][['name', 'total_points', 'was_home', 'opponent_attack_strength', 'opponent_defence_strength', 'opp_xgc']]
    next_weeks = temp2.groupby('name').agg({'opponent_attack_strength': 'mean', 'opponent_defence_strength': 'mean', 'was_home': 'sum', 'total_points': 'sum', 'opp_xgc': 'mean'}).round(2)
    next_weeks.rename(columns={'total_points': 'next_weeks_points', 'was_home': 'is_home', 'opponent_attack_strength': 'nw_opp_att', 'opponent_defence_strength': 'nw_opp_def', 'opp_xgc': 'nw_opp_xgc'}, inplace=True)
    next_weeks['is_home'] = next_weeks['is_home'].astype(int)
    temp2 = prev_weeks.merge(next_weeks, on='name', how='left')
    full_data = pd.concat([full_data, temp2])
    gw+=1

# %%
full_data['ppm'] = round(full_data['last_week_points_sum']/full_data['value'], 2)

full_data['points_per_minute'] = full_data['last_week_points_sum']/full_data['minutes']
full_data['xg_per90'] = full_data['expected_goals']/full_data['minutes']*90
full_data['xa_per90'] = full_data['expected_assists']/full_data['minutes']*90
full_data['xgi_per90'] = full_data['expected_goal_involvements']/full_data['minutes']*90
full_data['xgc_per90'] = full_data['expected_goals_conceded']/full_data['minutes']*90

#expected goal involvements per million; could this be a good way to determine which players are "undervalued"?
full_data['xgi_pm'] = round(full_data['expected_goal_involvements']/full_data['value'], 2)
full_data['xg_pm'] = round(full_data['expected_goals']/full_data['value'], 2)
full_data['xa_pm'] = round(full_data['expected_assists']/full_data['value'], 2)

# %%
full_data.loc[full_data['position'] == 'GK'].corr()['next_weeks_points'].sort_values(ascending=False).head(15)
# Out:
# next_weeks_points             1.000000
# starts                        0.414599
# minutes                       0.403624
# bps                           0.354542
# last_week_points_mean         0.302138
# weighted_points               0.298569
# last_week_points_sum          0.288478
# ppm                           0.274843
# last_week_points_std          0.252132
# weighted_xgi                  0.250346
# clean_sheets                  0.245395
# expected_goals_conceded       0.227205
# expected_assists              0.227016
# expected_goal_involvements    0.227016
# saves                         0.222328
# Name: next_weeks_points, dtype: float64

# %%
full_data.loc[full_data['position'] == 'GK'].corr()['next_weeks_points'].sort_values(ascending=True).head(15)
# Out:
# xgc_per90                   -0.129841
# opponent_defense_strength   -0.114495
# opponent_attack_strength    -0.110655
# GW                          -0.086688
# penalties_saved             -0.072381
# gc_vs_xgc                   -0.059964
# nw_opp_att                  -0.054862
# was_home                    -0.046351
# gi_vs_xgi                   -0.012567
# nw_opp_def                  -0.005416
# assists                      0.037118
# goal_involvements            0.037118
# own_goals                    0.050242
# nw_opp_xgc                   0.050256
# points_per_minute            0.055605
# Name: next_weeks_points, dtype: float64

# %%
full_data.loc[full_data['position'] == 'DEF'].corr()['next_weeks_points'].sort_values(ascending=False).head(15)
# Out:
# next_weeks_points             1.000000
# bps                           0.255438
# last_week_points_mean         0.242292
# weighted_points               0.242202
# last_week_points_sum          0.230067
# minutes                       0.204568
# expected_goal_involvements    0.198220
# value                         0.195961
# starts                        0.194427
# ppm                           0.193834
# expected_assists              0.192266
# weighted_xgi                  0.190579
# team_tier                     0.186078
# clean_sheets                  0.180057
# xgi_pm                        0.179846
# Name: next_weeks_points, dtype: float64

# %%
full_data.loc[full_data['position'] == 'DEF'].corr()['next_weeks_points'].sort_values(ascending=True).head(15)
# Out:
# nw_opp_att                  -0.102656
# xgc_per90                   -0.093335
# nw_opp_def                  -0.077129
# opponent_defense_strength   -0.069215
# opponent_attack_strength    -0.050617
# gc_vs_xgc                   -0.019097
# GW                          -0.008825
# g_vs_xg                     -0.006431
# points_per_minute           -0.002094
# own_goals                   -0.001992
# was_home                     0.004888
# red_cards                    0.016771
# opp_xgc                      0.018353
# yellow_cards                 0.028043
# goals_conceded               0.039174
# Name: next_weeks_points, dtype: float64

# %%
full_data.loc[full_data['position'] == 'MID'].corr()['next_weeks_points'].sort_values(ascending=False).head(15)
# Out:
# next_weeks_points             1.000000
# expected_goal_involvements    0.413487
# weighted_xgi                  0.409611
# last_week_points_mean         0.378452
# weighted_points               0.378345
# expected_assists              0.360003
# xgi_pm                        0.359951
# last_week_points_sum          0.356574
# goal_involvements             0.349589
# expected_goals                0.344934
# value                         0.335984
# bps                           0.329461
# goals_scored                  0.308443
# xg_pm                         0.293666
# xa_pm                         0.290316
# Name: next_weeks_points, dtype: float64

# %%
full_data.loc[full_data['position'] == 'MID'].corr()['next_weeks_points'].sort_values(ascending=True).head(15)
# Out:
# xgc_per90                   -0.117212
# nw_opp_att                  -0.080124
# nw_opp_def                  -0.059787
# red_cards                   -0.047084
# gc_vs_xgc                   -0.039279
# opponent_defense_strength   -0.018982
# GW                          -0.007410
# opponent_attack_strength    -0.007236
# yellow_cards                -0.006236
# opp_xgc                     -0.005830
# was_home                     0.003722
# penalties_missed             0.015589
# own_goals                    0.016010
# promoted                     0.017263
# nw_opp_xgc                   0.038181
# Name: next_weeks_points, dtype: float64

# %%
full_data.loc[full_data['position'] == 'FWD'].corr()['next_weeks_points'].sort_values(ascending=False).head(15)
# Out:
# next_weeks_points             1.000000
# minutes                       0.262139
# last_week_points_mean         0.255927
# expected_goal_involvements    0.254019
# weighted_points               0.253795
# weighted_xgi                  0.251655
# value                         0.243500
# expected_goals                0.235226
# goal_involvements             0.226897
# bps                           0.215866
# last_week_points_sum          0.211173
# starts                        0.201418
# goals_scored                  0.201080
# xgi_pm                        0.200492
# is_home                       0.182421
# Name: next_weeks_points, dtype: float64

# %%
full_data.loc[full_data['position'] == 'FWD'].corr()['next_weeks_points'].sort_values(ascending=True).head(15)
# Out:
# xgc_per90                   -0.120698
# nw_opp_att                  -0.088908
# red_cards                   -0.068580
# points_per_minute           -0.043819
# nw_opp_def                  -0.022911
# opponent_attack_strength    -0.014472
# opponent_defense_strength    0.000601
# g_vs_xg                      0.005193
# opp_xgc                      0.012150
# xa_per90                     0.012568
# GW                           0.044156
# yellow_cards                 0.064135
# gc_vs_xgc                    0.065641
# gi_vs_xgi                    0.070104
# was_home                     0.074668
# Name: next_weeks_points, dtype: float64

# %%
full_data.columns
# Out:
# Index(['name', 'position', 'team', 'team_tier', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'expected_assists', 'expected_goal_involvements',
#        'expected_goals', 'expected_goals_conceded', 'goals_conceded',
#        'goals_scored', 'minutes', 'own_goals', 'penalties_missed',
#        'penalties_saved', 'red_cards', 'saves', 'starts',
#        'last_week_points_mean', 'last_week_points_sum', 'last_week_points_std',
#        'was_home', 'yellow_cards', 'opp_xgc', 'opponent_attack_strength',
#        'opponent_defense_strength', 'goal_involvements', 'promoted', 'g_vs_xg',
#        'gi_vs_xgi', 'gc_vs_xgc', 'weighted_points', 'weighted_xgi', 'value',
#        'GW', 'nw_opp_att', 'nw_opp_def', 'is_home', 'next_weeks_points',
#        'nw_opp_xgc', 'ppm', 'points_per_minute', 'xg_per90', 'xa_per90',
#        'xgi_per90', 'xgc_per90', 'xgi_pm', 'xg_pm', 'xa_pm'],
#       dtype='object')

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7407 entries, 0 to 266
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   name                        7407 non-null   object
#  1   position                    7407 non-null   object
#  2   team                        7407 non-null   object
#  3   team_tier                   7407 non-null   float64
#  4   assists                     7407 non-null   float64
#  5   bonus                       7407 non-null   float64
#  6   bps                         7407 non-null   float64
#  7   clean_sheets                7407 non-null   float64
#  8   expected_assists            7407 non-null   float64
#  9   expected_goal_involvements  7407 non-null   float64
#  10  expected_goals              7407 non-null   float64
#  11  expected_goals_conceded     7407 non-null   float64
#  12  goals_conceded              7407 non-null   float64
#  13  goals_scored                7407 non-null   float64
#  14  minutes                     7407 non-null   float64
#  15  own_goals                   7407 non-null   float64
#  16  penalties_missed            7407 non-null   float64
#  17  penalties_saved             7407 non-null   float64
#  18  red_cards                   7407 non-null   float64
#  19  saves                       7407 non-null   float64
#  20  starts                      7407 non-null   float64
#  21  last_week_points_mean       7407 non-null   float64
#  22  last_week_points_sum        7407 non-null   int64
#  23  last_week_points_std        7402 non-null   float64
#  24  was_home                    7407 non-null   float64
#  25  yellow_cards                7407 non-null   float64
#  26  opp_xgc                     7407 non-null   float64
#  27  opponent_attack_strength    7407 non-null   float64
#  28  opponent_defense_strength   7407 non-null   float64
#  29  goal_involvements           7407 non-null   float64
#  30  promoted                    7407 non-null   float64
#  31  g_vs_xg                     7407 non-null   float64
#  32  gi_vs_xgi                   7407 non-null   float64
#  33  gc_vs_xgc                   7407 non-null   float64
#  34  weighted_points             7407 non-null   float64
#  35  weighted_xgi                7407 non-null   float64
#  36  value                       7407 non-null   float64
#  37  GW                          7407 non-null   int64
#  38  nw_opp_att                  7407 non-null   float64
#  39  nw_opp_def                  7407 non-null   float64
#  40  is_home                     7407 non-null   int32
#  41  next_weeks_points           7407 non-null   int64
#  42  nw_opp_xgc                  7407 non-null   float64
#  43  ppm                         7407 non-null   float64
#  44  points_per_minute           7057 non-null   float64
#  45  xg_per90                    7055 non-null   float64
#  46  xa_per90                    7055 non-null   float64
#  47  xgi_per90                   7055 non-null   float64
#  48  xgc_per90                   7055 non-null   float64
#  49  xgi_pm                      7407 non-null   float64
#  50  xg_pm                       7407 non-null   float64
#  51  xa_pm                       7407 non-null   float64
# dtypes: float64(45), int32(1), int64(3), object(3)
# memory usage: 3.0+ MB

# %%
full_data.replace([np.inf, -np.inf], np.nan, inplace=True)
full_data.fillna(0, inplace=True)
#full_data.drop('name', axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from category_encoders.cat_boost import CatBoostEncoder

X = full_data.drop('next_weeks_points', axis=1).reset_index(drop=True)
y = full_data['next_weeks_points'].reset_index(drop=True)

cat_col = ['position', 'team']
enc = OneHotEncoder(handle_unknown='ignore', sparse=False)
one_hot_encoded = enc.fit_transform(X[cat_col])
one_hot_df = pd.DataFrame(one_hot_encoded, columns=enc.get_feature_names_out(cat_col)).reset_index(drop=True)
cat_enc = CatBoostEncoder()
cat_encoded = cat_enc.fit_transform(X['name'], y)
cat_enc_df = pd.DataFrame(cat_encoded, columns=cat_enc.get_feature_names_out('name')).reset_index(drop=True)

df_encoded = pd.concat([X, one_hot_df, cat_enc_df], axis=1)
df_encoded.drop(cat_col+['name'], axis=1, inplace=True)

X_train, X_test, y_train, y_test = train_test_split(df_encoded, y, test_size=0.2, random_state=442)

# %%
from sklearn.preprocessing import StandardScaler

std_scaler_train = StandardScaler()
std_scaler_test = StandardScaler()

X_train_s = std_scaler_train.fit_transform(X_train)
X_test_s = std_scaler_train.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_absolute_error as MAE

model = LinearRegression()
model.fit(X_train_s, y_train)
pred = model.predict(X_test_s)
rmse = np.sqrt(MSE(y_test, pred))
mae = MAE(y_test, pred)
print("RMSE : % f" %(rmse)) 
print("MAE : % f" %(mae))
# Out:
# RMSE :  8.199869
# MAE :  6.352275

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [3, 6, 9],
    'learning_rate': [0.1, 0.05, 0.01],
    'subsample': [0.5, 0.75, 1],
    'colsample_bytree': [0.5, 0.75, 1],
    'n_estimators': [500, 1000, 1500],
    'lambda': [1, 3, 5]
}

reg = xgb.XGBRegressor()
grid_search = GridSearchCV(reg, param_grid, cv=5, scoring='neg_mean_absolute_error', verbose=3)
grid_search.fit(X_train, y_train)
print("Best score: ", grid_search.best_score_)
print("Best set of hyperparameters: ", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.5;, score=-5.739 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.5;, score=-5.508 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.5;, score=-5.814 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.5;, score=-5.891 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.5;, score=-5.712 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.75;, score=-5.635 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.75;, score=-5.480 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.75;, score=-5.692 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.75;, score=-5.834 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.75;, score=-5.651 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1;, score=-5.648 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1;, score=-5.528 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1;, score=-5.755 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1;, score=-5.760 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1;, score=-5.713 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.5;, score=-5.602 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.5;, score=-5.345 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.5;, score=-5.691 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.5;, score=-5.770 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.5;, score=-5.543 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.75;, score=-5.544 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.75;, score=-5.393 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.75;, score=-5.551 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.75;, score=-5.695 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.75;, score=-5.474 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1;, score=-5.550 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1;, score=-5.359 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1;, score=-5.660 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1;, score=-5.629 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1;, score=-5.568 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.563 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.287 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.599 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.702 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.469 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.503 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.335 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.487 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.596 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.381 total time=   0.9s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=1;, score=-5.486 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=1;, score=-5.274 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=1;, score=-5.561 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=1;, score=-5.585 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=3, n_estimators=1500, subsample=1;, score=-5.514 total time=   0.9s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.323 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.152 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.261 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.424 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.191 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.146 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.75;, score=-4.977 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.173 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.242 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.067 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1;, score=-5.084 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1;, score=-4.948 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1;, score=-5.161 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1;, score=-5.140 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1;, score=-5.077 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.265 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.106 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.209 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.358 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.129 total time=   1.3s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.75;, score=-5.096 total time=   1.4s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.75;, score=-4.925 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.75;, score=-5.116 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.75;, score=-5.172 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=0.75;, score=-5.032 total time=   1.4s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=1;, score=-5.046 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=1;, score=-4.883 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=1;, score=-5.098 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=1;, score=-5.075 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1000, subsample=1;, score=-5.015 total time=   1.4s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=0.5;, score=-5.259 total time=   2.2s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=0.5;, score=-5.093 total time=   2.2s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=0.5;, score=-5.198 total time=   2.2s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=0.5;, score=-5.342 total time=   2.2s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=0.5;, score=-5.118 total time=   2.2s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=0.75;, score=-5.091 total time=   2.2s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=0.75;, score=-4.915 total time=   2.2s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=0.75;, score=-5.109 total time=   2.2s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=0.75;, score=-5.159 total time=   2.2s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=0.75;, score=-5.025 total time=   2.4s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=1;, score=-5.039 total time=   2.1s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=1;, score=-4.871 total time=   2.0s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=1;, score=-5.089 total time=   2.0s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=1;, score=-5.057 total time=   2.2s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=6, n_estimators=1500, subsample=1;, score=-5.008 total time=   2.1s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=0.5;, score=-5.307 total time=   2.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=0.5;, score=-5.044 total time=   2.1s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=0.5;, score=-5.343 total time=   2.2s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=0.5;, score=-5.299 total time=   2.1s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=0.5;, score=-5.316 total time=   2.2s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=0.75;, score=-5.051 total time=   2.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=0.75;, score=-4.853 total time=   2.4s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=0.75;, score=-5.071 total time=   2.4s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=0.75;, score=-5.183 total time=   2.4s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=0.75;, score=-5.077 total time=   2.4s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=1;, score=-5.032 total time=   2.1s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=1;, score=-4.963 total time=   2.2s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=1;, score=-5.083 total time=   2.3s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=1;, score=-5.139 total time=   2.1s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=500, subsample=1;, score=-5.069 total time=   2.3s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=0.5;, score=-5.304 total time=   4.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=0.5;, score=-5.043 total time=   4.3s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=0.5;, score=-5.344 total time=   4.2s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=0.5;, score=-5.297 total time=   4.3s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=0.5;, score=-5.315 total time=   4.3s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=0.75;, score=-5.051 total time=   4.7s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=0.75;, score=-4.853 total time=   4.5s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=0.75;, score=-5.070 total time=   4.5s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=0.75;, score=-5.181 total time=   4.6s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=0.75;, score=-5.076 total time=   4.4s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=1;, score=-5.029 total time=   4.0s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=1;, score=-4.961 total time=   4.0s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=1;, score=-5.081 total time=   4.0s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=1;, score=-5.135 total time=   5.9s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1000, subsample=1;, score=-5.067 total time=   4.0s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=0.5;, score=-5.303 total time=   6.0s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=0.5;, score=-5.043 total time=   5.8s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=0.5;, score=-5.343 total time=   5.8s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=0.5;, score=-5.295 total time=   6.5s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=0.5;, score=-5.313 total time=   5.9s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=0.75;, score=-5.051 total time=   5.6s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=0.75;, score=-4.852 total time=   5.4s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=0.75;, score=-5.069 total time=   5.7s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=0.75;, score=-5.180 total time=   5.6s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=0.75;, score=-5.076 total time=   5.9s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=1;, score=-5.029 total time=   5.4s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=1;, score=-4.961 total time=   5.8s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=1;, score=-5.081 total time=   4.6s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=1;, score=-5.135 total time=   4.7s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.1, max_depth=9, n_estimators=1500, subsample=1;, score=-5.067 total time=   4.5s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=0.5;, score=-5.717 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=0.5;, score=-5.581 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=0.5;, score=-5.889 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=0.5;, score=-5.951 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=0.5;, score=-5.890 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=0.75;, score=-5.684 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=0.75;, score=-5.620 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=0.75;, score=-5.866 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=0.75;, score=-5.902 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=0.75;, score=-5.863 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=1;, score=-5.733 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=1;, score=-5.662 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=1;, score=-5.916 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=1;, score=-5.863 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=500, subsample=1;, score=-5.888 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=0.5;, score=-5.614 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=0.5;, score=-5.464 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=0.5;, score=-5.779 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=0.5;, score=-5.833 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=0.5;, score=-5.688 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=0.75;, score=-5.570 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=0.75;, score=-5.453 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=0.75;, score=-5.723 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=0.75;, score=-5.736 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=0.75;, score=-5.695 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=1;, score=-5.623 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=1;, score=-5.521 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=1;, score=-5.773 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=1;, score=-5.754 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1000, subsample=1;, score=-5.752 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.562 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.408 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.686 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.726 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.559 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.512 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.349 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.613 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.670 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.587 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=1;, score=-5.567 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=1;, score=-5.410 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=1;, score=-5.707 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=1;, score=-5.701 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=3, n_estimators=1500, subsample=1;, score=-5.635 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.281 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.051 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.343 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.436 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.241 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.219 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.028 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.199 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.300 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.161 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=1;, score=-5.293 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=1;, score=-5.075 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=1;, score=-5.295 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=1;, score=-5.282 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=500, subsample=1;, score=-5.143 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.166 total time=   1.7s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=0.5;, score=-4.933 total time=   1.6s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.192 total time=   1.7s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.291 total time=   1.6s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.077 total time=   1.6s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=0.75;, score=-5.085 total time=   1.6s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=0.75;, score=-4.898 total time=   1.6s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=0.75;, score=-5.059 total time=   1.7s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=0.75;, score=-5.130 total time=   1.7s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=0.75;, score=-5.002 total time=   1.7s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=1;, score=-5.179 total time=   1.7s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=1;, score=-4.921 total time=   1.6s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=1;, score=-5.139 total time=   1.5s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=1;, score=-5.128 total time=   1.5s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=1;, score=-4.977 total time=   1.6s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=0.5;, score=-5.144 total time=   2.5s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=0.5;, score=-4.891 total time=   2.6s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=0.5;, score=-5.139 total time=   2.7s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=0.5;, score=-5.234 total time=   2.6s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=0.5;, score=-5.032 total time=   2.6s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=0.75;, score=-5.058 total time=   2.6s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=0.75;, score=-4.858 total time=   2.5s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=0.75;, score=-5.018 total time=   2.8s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=0.75;, score=-5.077 total time=   2.7s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=0.75;, score=-4.954 total time=   2.7s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=1;, score=-5.149 total time=   2.4s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=1;, score=-4.876 total time=   2.4s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=1;, score=-5.085 total time=   2.5s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=1;, score=-5.080 total time=   2.4s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=6, n_estimators=1500, subsample=1;, score=-4.942 total time=   2.5s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=0.5;, score=-5.164 total time=   2.6s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=0.5;, score=-4.965 total time=   2.6s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=0.5;, score=-5.139 total time=   2.5s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=0.5;, score=-5.265 total time=   2.5s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=0.5;, score=-5.143 total time=   2.4s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=0.75;, score=-5.001 total time=   2.7s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=0.75;, score=-4.880 total time=   2.8s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=0.75;, score=-5.124 total time=   2.7s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=0.75;, score=-5.101 total time=   2.7s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=0.75;, score=-4.987 total time=   2.7s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=1;, score=-4.978 total time=   2.8s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=1;, score=-4.862 total time=   2.7s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=1;, score=-5.067 total time=   2.5s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=1;, score=-5.062 total time=   2.5s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=500, subsample=1;, score=-4.991 total time=   2.5s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=0.5;, score=-5.134 total time=   5.0s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=0.5;, score=-4.928 total time=   5.3s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=0.5;, score=-5.104 total time=   5.2s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=0.5;, score=-5.213 total time=   5.1s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=0.5;, score=-5.116 total time=   5.3s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=0.75;, score=-4.983 total time=   5.7s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=0.75;, score=-4.859 total time=   5.4s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=0.75;, score=-5.107 total time=   5.7s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=0.75;, score=-5.077 total time=   5.8s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=0.75;, score=-4.970 total time=   5.6s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=1;, score=-4.964 total time=   6.7s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=1;, score=-4.839 total time=   5.1s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=1;, score=-5.039 total time=   4.8s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=1;, score=-5.029 total time=   5.4s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1000, subsample=1;, score=-4.965 total time=   5.1s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=0.5;, score=-5.132 total time=   8.8s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=0.5;, score=-4.925 total time=   8.4s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=0.5;, score=-5.101 total time=   7.7s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=0.5;, score=-5.209 total time=   7.2s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=0.5;, score=-5.114 total time=   7.0s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=0.75;, score=-4.982 total time=   7.9s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=0.75;, score=-4.857 total time=   8.0s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=0.75;, score=-5.106 total time=   7.5s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=0.75;, score=-5.075 total time=   7.9s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=0.75;, score=-4.969 total time=   7.6s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=1;, score=-4.962 total time=   7.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=1;, score=-4.837 total time=   8.1s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=1;, score=-5.037 total time=   8.4s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=1;, score=-5.026 total time=   6.8s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.05, max_depth=9, n_estimators=1500, subsample=1;, score=-4.963 total time=   7.1s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.5;, score=-5.965 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.5;, score=-5.951 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.5;, score=-6.136 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.5;, score=-6.156 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.5;, score=-6.204 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.75;, score=-5.954 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.75;, score=-5.962 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.75;, score=-6.140 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.75;, score=-6.151 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.75;, score=-6.196 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1;, score=-5.958 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1;, score=-5.971 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1;, score=-6.126 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1;, score=-6.145 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1;, score=-6.207 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.5;, score=-5.853 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.5;, score=-5.801 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.5;, score=-6.018 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.5;, score=-6.051 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.5;, score=-6.072 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.75;, score=-5.845 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.75;, score=-5.808 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.75;, score=-6.015 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.75;, score=-6.023 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.75;, score=-6.062 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1;, score=-5.849 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1;, score=-5.842 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1;, score=-6.013 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1;, score=-6.021 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1;, score=-6.079 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.798 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.715 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.945 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.988 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.975 total time=   1.3s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.777 total time=   1.2s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.721 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.948 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.949 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.970 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=1;, score=-5.781 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=1;, score=-5.762 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=1;, score=-5.958 total time=   1.2s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=1;, score=-5.960 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=1;, score=-5.996 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.656 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.510 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.774 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.773 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.782 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.575 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.517 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.706 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.717 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.759 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1;, score=-5.552 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1;, score=-5.492 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1;, score=-5.720 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1;, score=-5.711 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1;, score=-5.748 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.466 total time=   1.5s
# [CV 2/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.249 total time=   1.6s
# [CV 3/5] END colsample_bytree=0.5, lambda=1, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.560 total time=   1.5s
# ...
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.75;, score=-6.057 total time=   0.7s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1;, score=-5.871 total time=   0.6s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1;, score=-5.851 total time=   0.6s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1;, score=-6.023 total time=   0.6s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1;, score=-6.032 total time=   0.6s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1;, score=-6.088 total time=   0.6s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.778 total time=   1.0s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.686 total time=   1.0s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.931 total time=   1.1s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.959 total time=   1.0s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.5;, score=-5.965 total time=   1.1s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.785 total time=   1.0s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.689 total time=   1.0s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.924 total time=   1.0s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.938 total time=   1.1s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=0.75;, score=-5.964 total time=   1.0s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=1;, score=-5.808 total time=   1.0s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=1;, score=-5.781 total time=   1.0s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=1;, score=-5.958 total time=   1.0s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=1;, score=-5.973 total time=   1.0s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=3, n_estimators=1500, subsample=1;, score=-6.003 total time=   1.0s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.610 total time=   0.9s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.489 total time=   0.8s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.743 total time=   0.8s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.810 total time=   0.8s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5;, score=-5.773 total time=   0.8s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.539 total time=   0.8s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.479 total time=   0.8s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.687 total time=   0.8s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.729 total time=   0.8s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.75;, score=-5.739 total time=   0.9s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1;, score=-5.572 total time=   0.9s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1;, score=-5.533 total time=   0.8s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1;, score=-5.742 total time=   0.7s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1;, score=-5.751 total time=   0.8s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1;, score=-5.745 total time=   0.8s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.443 total time=   1.6s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.222 total time=   1.7s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.515 total time=   1.7s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.611 total time=   1.7s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.5;, score=-5.497 total time=   1.7s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.75;, score=-5.339 total time=   1.7s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.75;, score=-5.199 total time=   1.7s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.75;, score=-5.443 total time=   1.7s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.75;, score=-5.510 total time=   1.7s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=0.75;, score=-5.469 total time=   1.7s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=1;, score=-5.425 total time=   1.6s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=1;, score=-5.308 total time=   1.6s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=1;, score=-5.572 total time=   1.6s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=1;, score=-5.610 total time=   1.6s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1000, subsample=1;, score=-5.496 total time=   1.6s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=0.5;, score=-5.322 total time=   2.9s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=0.5;, score=-5.091 total time=   2.6s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=0.5;, score=-5.378 total time=   2.6s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=0.5;, score=-5.481 total time=   2.6s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=0.5;, score=-5.323 total time=   2.7s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=0.75;, score=-5.220 total time=   2.7s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=0.75;, score=-5.053 total time=   2.6s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=0.75;, score=-5.288 total time=   2.6s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=0.75;, score=-5.374 total time=   2.7s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=0.75;, score=-5.308 total time=   2.6s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=1;, score=-5.336 total time=   2.5s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=1;, score=-5.179 total time=   2.6s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=1;, score=-5.462 total time=   2.6s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=1;, score=-5.504 total time=   2.5s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=6, n_estimators=1500, subsample=1;, score=-5.364 total time=   2.5s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=0.5;, score=-5.327 total time=   2.4s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=0.5;, score=-5.182 total time=   2.4s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=0.5;, score=-5.437 total time=   2.3s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=0.5;, score=-5.558 total time=   2.3s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=0.5;, score=-5.466 total time=   2.4s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=0.75;, score=-5.246 total time=   2.7s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=0.75;, score=-5.146 total time=   2.7s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=0.75;, score=-5.330 total time=   2.6s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=0.75;, score=-5.419 total time=   2.7s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=0.75;, score=-5.339 total time=   3.0s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=1;, score=-5.211 total time=   2.8s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=1;, score=-5.184 total time=   2.8s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=1;, score=-5.335 total time=   2.7s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=1;, score=-5.429 total time=   2.9s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=500, subsample=1;, score=-5.409 total time=   3.0s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=0.5;, score=-5.139 total time=   4.9s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=0.5;, score=-4.935 total time=   5.1s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=0.5;, score=-5.188 total time=   5.2s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=0.5;, score=-5.320 total time=   5.2s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=0.5;, score=-5.189 total time=   5.1s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=0.75;, score=-5.047 total time=   5.7s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=0.75;, score=-4.882 total time=   5.7s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=0.75;, score=-5.100 total time=   5.6s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=0.75;, score=-5.194 total time=   5.9s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=0.75;, score=-5.082 total time=   5.8s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=1;, score=-5.047 total time=   5.4s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=1;, score=-4.974 total time=   5.5s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=1;, score=-5.145 total time=   5.5s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=1;, score=-5.257 total time=   5.5s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1000, subsample=1;, score=-5.183 total time=   5.9s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=0.5;, score=-5.051 total time=   8.2s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=0.5;, score=-4.828 total time=   8.0s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=0.5;, score=-5.081 total time=   8.2s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=0.5;, score=-5.207 total time=   8.3s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=0.5;, score=-5.064 total time=   8.1s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=0.75;, score=-4.975 total time=   9.1s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=0.75;, score=-4.784 total time=   8.9s
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=0.75;, score=-4.995 total time=   9.1s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=0.75;, score=-5.093 total time=   9.0s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=0.75;, score=-4.972 total time=   9.0s
# [CV 1/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=1;, score=-4.983 total time=   8.3s
# [CV 2/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=1;, score=-4.884 total time=45.2min
# [CV 3/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=1;, score=-5.071 total time=   8.6s
# [CV 4/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=1;, score=-5.189 total time=   8.5s
# [CV 5/5] END colsample_bytree=1, lambda=5, learning_rate=0.01, max_depth=9, n_estimators=1500, subsample=1;, score=-5.078 total time=   8.5s
# Best score:  -4.909338124341602
# Best set of hyperparameters:  {'colsample_bytree': 1, 'lambda': 5, 'learning_rate': 0.05, 'max_depth': 9, 'n_estimators': 1500, 'subsample': 0.75}

# %%
#reg.fit(X_train_s, y_train)
#pred = reg.predict(X_test_s)
pred = grid_search.predict(X_test_s) 
rmse = np.sqrt(MSE(y_test, pred))
mae = MAE(y_test, pred)
print("RMSE : % f" %(rmse))
print("MAE : % f" %(mae))
# Out:
# RMSE :  8.981918
# MAE :  7.058685

# %%
'''prediction_test = X_test.copy()
prediction_test['y'] = y_test
prediction_test['pred'] = pred'''
# Out:
# "prediction_test = X_test.copy()\nprediction_test['y'] = y_test\nprediction_test['pred'] = pred"

# %%
import pickle
file_name = "xgb_reg.pkl"

# save
pickle.dump(grid_search, open(file_name, "wb"))
