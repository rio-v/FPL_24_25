# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import fpl_functions as fpl
pd.options.mode.chained_assignment = None
sns.set_theme()

# %%
url = "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2023-24/gws/merged_gw.csv"

df = pd.read_csv(url)

# %%
df.head().T
# Out:
#                                                0                     1  \
# name                                 Femi Seriki      Jack Hinshelwood
# position                                     DEF                   MID
# team                               Sheffield Utd              Brighton
# xP                                           0.5                   1.5
# assists                                        0                     0
# bonus                                          0                     0
# bps                                            0                     0
# clean_sheets                                   0                     0
# creativity                                   0.0                   0.0
# element                                      653                   621
# expected_assists                             0.0                   0.0
# expected_goal_involvements                   0.0                   0.0
# expected_goals                               0.0                   0.0
# expected_goals_conceded                      0.0                   0.0
# fixture                                        7                     4
# goals_conceded                                 0                     0
# goals_scored                                   0                     0
# ict_index                                    0.0                   0.0
# influence                                    0.0                   0.0
# kickoff_time                2023-08-12T14:00:00Z  2023-08-12T14:00:00Z
# minutes                                        0                     0
# opponent_team                                  8                    12
# own_goals                                      0                     0
# penalties_missed                               0                     0
# penalties_saved                                0                     0
# red_cards                                      0                     0
# round                                          1                     1
# saves                                          0                     0
# selected                                       0                   822
# starts                                         0                     0
# team_a_score                                   1                     1
# team_h_score                                   0                     4
# threat                                       0.0                   0.0
# total_points                                   0                     0
# transfers_balance                              0                     0
# transfers_in                                   0                     0
# transfers_out                                  0                     0
# value                                         40                    45
# was_home                                    True                  True
# yellow_cards                                   0                     0
# GW                                             1                     1
#
#                                                2                       3  \
# name                                Jadon Sancho  Rhys Norrington-Davies
# position                                     MID                     DEF
# team                                     Man Utd           Sheffield Utd
# xP                                           3.0                     0.1
# assists                                        0                       0
# bonus                                          0                       0
# bps                                            4                       0
# clean_sheets                                   0                       0
# creativity                                  11.3                     0.0
# element                                      397                     487
# expected_assists                            0.05                     0.0
# expected_goal_involvements                  0.05                     0.0
# expected_goals                               0.0                     0.0
# expected_goals_conceded                     1.08                     0.0
# fixture                                       10                       7
# goals_conceded                                 0                       0
# goals_scored                                   0                       0
# ict_index                                    2.3                     0.0
# influence                                    3.8                     0.0
# kickoff_time                2023-08-14T19:00:00Z    2023-08-12T14:00:00Z
# minutes                                       22                       0
# opponent_team                                 20                       8
# own_goals                                      0                       0
# penalties_missed                               0                       0
# penalties_saved                                0                       0
# red_cards                                      0                       0
# round                                          1                       1
# saves                                          0                       0
# selected                                   83993                    6456
# starts                                         0                       0
# team_a_score                                   0                       1
# team_h_score                                   1                       0
# threat                                       8.0                     0.0
# total_points                                   1                       0
# transfers_balance                              0                       0
# transfers_in                                   0                       0
# transfers_out                                  0                       0
# value                                         70                      40
# was_home                                    True                    True
# yellow_cards                                   0                       0
# GW                                             1                       1
#
#                                                4
# name                               Vitaly Janelt
# position                                     MID
# team                                   Brentford
# xP                                           2.1
# assists                                        0
# bonus                                          0
# bps                                            6
# clean_sheets                                   0
# creativity                                  11.5
# element                                      105
# expected_assists                            0.01
# expected_goal_involvements                  0.03
# expected_goals                              0.02
# expected_goals_conceded                     1.26
# fixture                                        8
# goals_conceded                                 2
# goals_scored                                   0
# ict_index                                    4.3
# influence                                   14.6
# kickoff_time                2023-08-13T13:00:00Z
# minutes                                       90
# opponent_team                                 18
# own_goals                                      0
# penalties_missed                               0
# penalties_saved                                0
# red_cards                                      0
# round                                          1
# saves                                          0
# selected                                    6508
# starts                                         1
# team_a_score                                   2
# team_h_score                                   2
# threat                                      17.0
# total_points                                   2
# transfers_balance                              0
# transfers_in                                   0
# transfers_out                                  0
# value                                         55
# was_home                                    True
# yellow_cards                                   0
# GW                                             1

# %%
df.columns
# Out:
# Index(['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals',
#        'expected_goals_conceded', 'fixture', 'goals_conceded', 'goals_scored',
#        'ict_index', 'influence', 'kickoff_time', 'minutes', 'opponent_team',
#        'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards',
#        'round', 'saves', 'selected', 'starts', 'team_a_score', 'team_h_score',
#        'threat', 'total_points', 'transfers_balance', 'transfers_in',
#        'transfers_out', 'value', 'was_home', 'yellow_cards'],
#       dtype='object')
