# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import fpl_function as fpl
pd.options.mode.chained_assignment = None
sns.set_theme()

# %%
GAMEWEEKS_PLAYED = 2

# %%
df = pd.read_excel('players_Gameweek_2.xlsx')
fixtures = pd.read_excel('fixtures.xlsx')

# %%
df.drop(df[df['status'] == 'u'].index, inplace=True)

df['now_cost'] = df['now_cost']/10

#create points per million (cost) column (ppm)
df['ppm'] = round(df['total_points']/df['now_cost'], 2)

#create expected goal involvements vs actual goal involvements column
df['gi_vs_xgi'] = df['goals_scored'] + df['assists'] - df['expected_goal_involvements']

df['goal_involvements'] = df['goals_scored'] + df['assists']

df['points_per_minute'] = df['total_points']/df['minutes']

df['gc_vs_xgc'] = df['goals_conceded'] - df['expected_goals_conceded']

df['percent_of_season_played'] = np.round(df['minutes']/(GAMEWEEKS_PLAYED*90) * 100, 2)

# %%
fixtures_going_forward = fixtures.loc[fixtures['Gameweek'] > GAMEWEEKS_PLAYED]

df['next_match'] = df['team'].apply(lambda x: list(fpl.fixtures_by_team(fixtures, x, GAMEWEEKS_PLAYED+1)[['opponent', 'h_or_a']].iloc[-1]))
df['next_5_FDRs'] = df['team'].apply(lambda x: list(fpl.fixtures_by_team(fixtures_going_forward, x, GAMEWEEKS_PLAYED+5)['FDR']))
df['next_5_avg_FDRs'] = df['next_5_FDRs'].apply(lambda x: np.mean(x))

# %%
fpl.top_players(df, 'Goalkeeper', 'expected_goals_conceded', True, 10)
# Out:
#           web_name       team  now_cost  selected_by_percent  bps  minutes  \
# 13        Ramsdale    Arsenal       4.4                  0.8    0        0
# 332        Iversen  Leicester       4.0                  0.7    0        0
# 342     Stolarczyk  Leicester       4.0                  0.0    0        0
# 346           Ward  Leicester       4.0                  2.6    0        0
# 366       Kelleher  Liverpool       4.5                  0.3    0        0
# 384         Carson   Man City       4.0                  0.2    0        0
# 398  Ortega Moreno   Man City       5.4                  0.7    0        0
# 410       Bayindir    Man Utd       4.5                  0.1    0        0
# 417         Heaton    Man Utd       4.0                  0.2    0        0
# 442       Dúbravka  Newcastle       4.4                  1.0    0        0
#
#      percent_of_season_played  ppm           next_match  next_5_avg_FDRs  \
# 13                        0.0  0.0     [Brighton, Home]              3.0
# 332                       0.0  0.0  [Aston Villa, Home]              3.0
# 342                       0.0  0.0  [Aston Villa, Home]              3.0
# 346                       0.0  0.0  [Aston Villa, Home]              3.0
# 366                       0.0  0.0      [Man Utd, Away]              2.4
# 384                       0.0  0.0     [West Ham, Away]              3.0
# 398                       0.0  0.0     [West Ham, Away]              3.0
# 410                       0.0  0.0    [Liverpool, Home]              3.2
# 417                       0.0  0.0    [Liverpool, Home]              3.2
# 442                       0.0  0.0        [Spurs, Home]              3.2
#
#      clean_sheets  saves  goals_conceded  expected_goals_conceded  gc_vs_xgc  \
# 13              0      0               0                      0.0        0.0
# 332             0      0               0                      0.0        0.0
# 342             0      0               0                      0.0        0.0
# 346             0      0               0                      0.0        0.0
# 366             0      0               0                      0.0        0.0
# 384             0      0               0                      0.0        0.0
# 398             0      0               0                      0.0        0.0
# 410             0      0               0                      0.0        0.0
# 417             0      0               0                      0.0        0.0
# 442             0      0               0                      0.0        0.0
#
#      total_points
# 13              0
# 332             0
# 342             0
# 346             0
# 366             0
# 384             0
# 398             0
# 410             0
# 417             0
# 442             0

# %%
fpl.top_players(df, 'Goalkeeper', 'gc_vs_xgc', True, 10)
# Out:
#      web_name         team  now_cost  selected_by_percent  bps  minutes  \
# 459      Pope    Newcastle       5.0                  8.6   41      180
# 14       Raya      Arsenal       5.5                 28.2   55      180
# 575    Areola     West Ham       4.5                  9.3   29      180
# 271      Leno       Fulham       5.0                  3.1   26      180
# 566   Vicario        Spurs       5.0                  4.1   46      180
# 75       Neto  Bournemouth       4.5                  2.5   30      180
# 149    Steele     Brighton       4.5                  2.3   46      180
# 96    Flekken    Brentford       4.5                 10.9   38      180
# 352  A.Becker    Liverpool       5.5                 10.8   53      180
# 523  McCarthy  Southampton       4.5                  0.2   21      180
#
#      percent_of_season_played   ppm           next_match  next_5_avg_FDRs  \
# 459                     100.0  2.40        [Spurs, Home]              3.2
# 14                      100.0  3.27     [Brighton, Home]              3.0
# 575                     100.0  1.56     [Man City, Home]              3.0
# 271                     100.0  1.20      [Ipswich, Away]              2.8
# 566                     100.0  1.60    [Newcastle, Away]              3.2
# 75                      100.0  1.56      [Everton, Away]              3.0
# 149                     100.0  2.00      [Arsenal, Away]              3.2
# 96                      100.0  1.56  [Southampton, Home]              3.0
# 352                     100.0  2.36      [Man Utd, Away]              2.4
# 523                     100.0  1.33    [Brentford, Away]              2.8
#
#      clean_sheets  saves  goals_conceded  expected_goals_conceded  gc_vs_xgc  \
# 459             1      6               1                     4.00      -3.00
# 14              2      6               0                     1.75      -1.75
# 575             1      3               2                     3.38      -1.38
# 271             0      7               2                     3.04      -1.04
# 566             1      3               1                     2.02      -1.02
# 75              0     11               2                     2.91      -0.91
# 149             1      3               1                     1.88      -0.88
# 96              0     12               3                     3.82      -0.82
# 352             2      4               0                     0.81      -0.81
# 523             0      7               2                     2.70      -0.70
#
#      total_points
# 459            12
# 14             18
# 575             7
# 271             6
# 566             8
# 75              7
# 149             9
# 96              7
# 352            13
# 523             6

# %%
fpl.top_players(df, 'Defender', 'expected_goal_involvements', False, 10)
# Out:
#              web_name           team  now_cost  selected_by_percent  bps  \
# 353  Alexander-Arnold      Liverpool       7.0                 30.3   60
# 499        Milenković  Nott'm Forest       4.5                  0.2   16
# 557            Romero          Spurs       5.1                  8.6   66
# 376         Robertson      Liverpool       6.0                  5.2   53
# 395             Lewis       Man City       4.6                  3.8   31
# 554       Pedro Porro          Spurs       5.5                 35.8   51
# 486        N.Williams  Nott'm Forest       4.5                  0.6   34
# 152           Veltman       Brighton       4.5                  2.5   50
# 251         Tarkowski        Everton       4.9                  1.5  -11
# 93            Collins      Brentford       4.5                  0.8   33
#
#      minutes  percent_of_season_played   ppm           next_match  \
# 353      147                     81.67  2.00      [Man Utd, Away]
# 499       90                     50.00  1.33       [Wolves, Home]
# 557      180                    100.00  3.14    [Newcastle, Away]
# 376      168                     93.33  2.00      [Man Utd, Away]
# 395      180                    100.00  1.74     [West Ham, Away]
# 554      180                    100.00  2.73    [Newcastle, Away]
# 486      180                    100.00  1.56       [Wolves, Home]
# 152      180                    100.00  2.22      [Arsenal, Away]
# 251      180                    100.00  0.00  [Bournemouth, Home]
# 93       180                    100.00  1.56  [Southampton, Home]
#
#      next_5_avg_FDRs  ...  assists  goal_involvements  \
# 353              2.4  ...        0                  0
# 499              3.0  ...        0                  0
# 557              3.2  ...        0                  1
# 376              2.4  ...        0                  0
# 395              3.0  ...        0                  0
# 554              3.2  ...        0                  1
# 486              3.0  ...        0                  0
# 152              3.2  ...        0                  0
# 251              2.6  ...        0                  0
# 93               3.0  ...        1                  1
#
#      expected_goal_involvements  gi_vs_xgi  expected_goal_involvements_per_90  \
# 353                        1.69      -1.69                               1.04
# 499                        0.99      -0.99                               0.99
# 557                        0.95       0.05                               0.47
# 376                        0.62      -0.62                               0.33
# 395                        0.60      -0.60                               0.30
# 554                        0.55       0.45                               0.28
# 486                        0.46      -0.46                               0.24
# 152                        0.45      -0.45                               0.22
# 251                        0.44      -0.44                               0.22
# 93                         0.37       0.63                               0.18
#
#      clean_sheets  goals_conceded  expected_goals_conceded  gc_vs_xgc  \
# 353             2               0                     0.77      -0.77
# 499             1               0                     0.14      -0.14
# 557             1               1                     2.02      -1.02
# 376             2               0                     0.77      -0.77
# 395             1               1                     1.30      -0.30
# 554             1               1                     1.96      -0.96
# 486             1               1                     1.36      -0.36
# 152             1               1                     1.88      -0.88
# 251             0               7                     3.86       3.14
# 93              0               3                     3.82      -0.82
#
#      total_points
# 353            14
# 499             6
# 557            16
# 376            12
# 395             8
# 554            15
# 486             7
# 152            10
# 251             0
# 93              7
#
# [10 rows x 21 columns]

# %%
fpl.top_players(df, 'Midfielder', 'expected_goal_involvements', False, 10)
# Out:
#         web_name         team  now_cost  selected_by_percent  bps  minutes  \
# 409  B.Fernandes      Man Utd       8.4                 14.7   25      168
# 80       Semenyo  Bournemouth       5.5                  2.7   45      180
# 368    Luis Díaz    Liverpool       7.5                  9.2   64      161
# 385    De Bruyne     Man City       9.6                 11.3   62      179
# 553     Maddison        Spurs       7.5                  5.2   50      156
# 358     Diogo J.    Liverpool       7.6                 19.8   43      149
# 369      M.Salah    Liverpool      12.6                 37.6   72      172
# 143       Mitoma     Brighton       6.6                  6.5   47      177
# 415     Garnacho      Man Utd       6.4                 13.8   11       54
# 561          Son        Spurs      10.0                 10.2   73      180
#
#      percent_of_season_played   ppm         next_match  next_5_avg_FDRs  \
# 409                     93.33  0.60  [Liverpool, Home]              3.2
# 80                     100.00  2.36    [Everton, Away]              3.0
# 368                     89.44  2.27    [Man Utd, Away]              2.4
# 385                     99.44  1.56   [West Ham, Away]              3.0
# 553                     86.67  1.47  [Newcastle, Away]              3.2
# 358                     82.78  1.84    [Man Utd, Away]              2.4
# 369                     95.56  1.90    [Man Utd, Away]              2.4
# 143                     98.33  2.12    [Arsenal, Away]              3.2
# 415                     30.00  0.78  [Liverpool, Home]              3.2
# 561                    100.00  1.80  [Newcastle, Away]              3.2
#
#      goals_scored  assists  goal_involvements  expected_goal_involvements  \
# 409             0        0                  0                        2.02
# 80              1        1                  2                        1.98
# 368             1        1                  2                        1.88
# 385             1        1                  2                        1.85
# 553             0        2                  2                        1.79
# 358             1        1                  2                        1.64
# 369             2        1                  3                        1.60
# 143             1        1                  2                        1.59
# 415             0        1                  1                        1.54
# 561             2        0                  2                        1.52
#
#      gi_vs_xgi  expected_goal_involvements_per_90  total_points
# 409      -2.02                               1.09             5
# 80        0.02                               1.00            13
# 368       0.12                               1.05            17
# 385       0.15                               0.93            15
# 553       0.21                               1.03            11
# 358       0.36                               0.99            14
# 369       1.40                               0.84            24
# 143       0.41                               0.81            14
# 415      -0.54                               2.57             5
# 561       0.48                               0.76            18

# %%
fpl.top_players(df, 'Midfielder', 'gi_vs_xgi', False, 10)
# Out:
#        web_name       team  now_cost  selected_by_percent  bps  minutes  \
# 196      Palmer    Chelsea      10.5                 39.6   79      172
# 191     Madueke    Chelsea       6.5                  8.4   76       90
# 16         Saka    Arsenal      10.0                 34.2   63      166
# 403       Sávio   Man City       6.5                  1.9   44      115
# 369     M.Salah  Liverpool      12.6                 37.6   72      172
# 121     Adingra   Brighton       5.5                  1.0   38       46
# 156     Wieffer   Brighton       5.0                  0.1   20       90
# 541    Bissouma      Spurs       5.0                  0.4   40       71
# 21     Trossard    Arsenal       6.9                  2.0   27       35
# 206  João Félix    Chelsea       6.5                  0.9   25       22
#
#      percent_of_season_played   ppm              next_match  next_5_avg_FDRs  \
# 196                     95.56  1.81  [Crystal Palace, Home]              2.0
# 191                     50.00  3.08  [Crystal Palace, Home]              2.0
# 16                      92.22  1.80        [Brighton, Home]              3.0
# 403                     63.89  1.54        [West Ham, Away]              3.0
# 369                     95.56  1.90         [Man Utd, Away]              2.4
# 121                     25.56  1.82         [Arsenal, Away]              3.2
# 156                     50.00  1.20         [Arsenal, Away]              3.2
# 541                     39.44  1.80       [Newcastle, Away]              3.2
# 21                      19.44  1.16        [Brighton, Home]              3.0
# 206                     12.22  0.92  [Crystal Palace, Home]              2.0
#
#      goals_scored  assists  goal_involvements  expected_goal_involvements  \
# 196             1        3                  4                        1.08
# 191             3        0                  3                        0.65
# 16              1        2                  3                        0.87
# 403             0        2                  2                        0.36
# 369             2        1                  3                        1.60
# 121             1        1                  2                        0.87
# 156             0        1                  1                        0.02
# 541             1        0                  1                        0.14
# 21              1        0                  1                        0.20
# 206             1        0                  1                        0.20
#
#      gi_vs_xgi  expected_goal_involvements_per_90  total_points
# 196       2.92                               0.57            19
# 191       2.35                               0.65            20
# 16        2.13                               0.47            18
# 403       1.64                               0.28            10
# 369       1.40                               0.84            24
# 121       1.13                               1.70            10
# 156       0.98                               0.02             6
# 541       0.86                               0.18             9
# 21        0.80                               0.51             8
# 206       0.80                               0.82             6

# %%
fpl.top_players(df, 'Midfielder', 'gi_vs_xgi', True, 10)
# Out:
#         web_name            team  now_cost  selected_by_percent  bps  minutes  \
# 409  B.Fernandes         Man Utd       8.4                 14.7   25      168
# 214          Eze  Crystal Palace       6.9                 26.1   28      180
# 240     Harrison         Everton       5.5                  0.2   10      140
# 12      Ødegaard         Arsenal       8.4                 12.6   20      180
# 246       McNeil         Everton       5.4                  0.7   30      180
# 586        Kudus        West Ham       6.4                  6.7   20      177
# 411     Casemiro         Man Utd       5.0                  0.7   32      180
# 8     Martinelli         Arsenal       7.0                  2.6   25      154
# 386         Doku        Man City       6.5                  4.5   34      160
# 483  Hudson-Odoi   Nott'm Forest       5.5                  3.0   37      161
#
#      percent_of_season_played   ppm           next_match  next_5_avg_FDRs  \
# 409                     93.33  0.60    [Liverpool, Home]              3.2
# 214                    100.00  0.58      [Chelsea, Away]              3.2
# 240                     77.78  0.55  [Bournemouth, Home]              2.6
# 12                     100.00  0.60     [Brighton, Home]              3.0
# 246                    100.00  0.74  [Bournemouth, Home]              2.6
# 586                     98.33  0.78     [Man City, Home]              3.0
# 411                    100.00  1.00    [Liverpool, Home]              3.2
# 8                       85.56  0.86     [Brighton, Home]              3.0
# 386                     88.89  0.77     [West Ham, Away]              3.0
# 483                     89.44  1.09       [Wolves, Home]              3.0
#
#      goals_scored  assists  goal_involvements  expected_goal_involvements  \
# 409             0        0                  0                        2.02
# 214             0        0                  0                        1.08
# 240             0        0                  0                        0.94
# 12              0        0                  0                        0.94
# 246             0        0                  0                        0.82
# 586             0        0                  0                        0.79
# 411             0        0                  0                        0.78
# 8               0        0                  0                        0.68
# 386             0        0                  0                        0.66
# 483             0        0                  0                        0.65
#
#      gi_vs_xgi  expected_goal_involvements_per_90  total_points
# 409      -2.02                               1.09             5
# 214      -1.08                               0.54             4
# 240      -0.94                               0.61             3
# 12       -0.94                               0.47             5
# 246      -0.82                               0.42             4
# 586      -0.79                               0.40             5
# 411      -0.78                               0.39             5
# 8        -0.68                               0.40             6
# 386      -0.66                               0.37             5
# 483      -0.65                               0.36             6

# %%
fpl.top_players(df, 'Forward', 'expected_goal_involvements', False, 10)
# Out:
#           web_name           team  now_cost  selected_by_percent  bps  \
# 391        Haaland       Man City      15.1                 60.0  111
# 155        Welbeck       Brighton       5.6                 10.3   79
# 607          Cunha         Wolves       6.5                  2.6   43
# 496           Wood  Nott'm Forest       6.1                  7.9   35
# 115          Wissa      Brentford       6.1                  6.3   54
# 57         Watkins    Aston Villa       9.0                 29.0    2
# 507      Armstrong    Southampton       5.5                  1.7    6
# 631  Strand Larsen         Wolves       5.5                  0.7   37
# 344          Vardy      Leicester       5.6                  7.0   36
# 90       Evanilson    Bournemouth       6.0                  0.3    7
#
#      minutes  percent_of_season_played   ppm             next_match  \
# 391      179                     99.44  1.59       [West Ham, Away]
# 155      168                     93.33  3.75        [Arsenal, Away]
# 607      100                     55.56  1.08  [Nott'm Forest, Away]
# 496      145                     80.56  1.64         [Wolves, Home]
# 115      155                     86.11  2.13    [Southampton, Home]
# 57       125                     69.44  0.44      [Leicester, Away]
# 507      160                     88.89  0.55      [Brentford, Away]
# 631      173                     96.11  1.45  [Nott'm Forest, Away]
# 344      148                     82.22  1.79    [Aston Villa, Home]
# 90        71                     39.44  0.33        [Everton, Away]
#
#      next_5_avg_FDRs  goals_scored  assists  goal_involvements  \
# 391              3.0             4        0                  4
# 155              3.2             2        1                  3
# 607              3.0             1        0                  1
# 496              3.0             1        0                  1
# 115              3.0             1        1                  2
# 57               2.2             0        0                  0
# 507              2.8             0        0                  0
# 631              3.0             1        0                  1
# 344              3.0             1        0                  1
# 90               3.0             0        0                  0
#
#      expected_goal_involvements  gi_vs_xgi  expected_goal_involvements_per_90  \
# 391                        2.11       1.89                               1.06
# 155                        1.37       1.63                               0.73
# 607                        1.21      -0.21                               1.09
# 496                        1.06      -0.06                               0.66
# 115                        1.02       0.98                               0.59
# 57                         0.87      -0.87                               0.63
# 507                        0.82      -0.82                               0.46
# 631                        0.82       0.18                               0.42
# 344                        0.80       0.20                               0.49
# 90                         0.75      -0.75                               0.95
#
#      total_points
# 391            24
# 155            21
# 607             7
# 496            10
# 115            13
# 57              4
# 507             3
# 631             8
# 344            10
# 90              2

# %%
fpl.top_players(df, 'Forward', 'bps', False, 10)
# Out:
#           web_name       team  now_cost  selected_by_percent  bps  minutes  \
# 391        Haaland   Man City      15.1                 60.0  111      179
# 155        Welbeck   Brighton       5.6                 10.3   79      168
# 115          Wissa  Brentford       6.1                  6.3   54      155
# 3          Havertz    Arsenal       8.1                 17.3   46      180
# 136     João Pedro   Brighton       5.5                 20.8   45      171
# 607          Cunha     Wolves       6.5                  2.6   43      100
# 194      N.Jackson    Chelsea       7.6                  4.7   42      132
# 431        Zirkzee    Man Utd       7.1                  4.2   38       74
# 631  Strand Larsen     Wolves       5.5                  0.7   37      173
# 344          Vardy  Leicester       5.6                  7.0   36      148
#
#      percent_of_season_played   ppm              next_match  next_5_avg_FDRs  \
# 391                     99.44  1.59        [West Ham, Away]              3.0
# 155                     93.33  3.75         [Arsenal, Away]              3.2
# 115                     86.11  2.13     [Southampton, Home]              3.0
# 3                      100.00  1.73        [Brighton, Home]              3.0
# 136                     95.00  1.82         [Arsenal, Away]              3.2
# 607                     55.56  1.08   [Nott'm Forest, Away]              3.0
# 194                     73.33  1.58  [Crystal Palace, Home]              2.0
# 431                     41.11  1.27       [Liverpool, Home]              3.2
# 631                     96.11  1.45   [Nott'm Forest, Away]              3.0
# 344                     82.22  1.79     [Aston Villa, Home]              3.0
#
#      goals_scored  assists  goal_involvements  expected_goal_involvements  \
# 391             4        0                  4                        2.11
# 155             2        1                  3                        1.37
# 115             1        1                  2                        1.02
# 3               1        1                  2                        0.73
# 136             1        0                  1                        0.70
# 607             1        0                  1                        1.21
# 194             1        1                  2                        0.71
# 431             1        0                  1                        0.10
# 631             1        0                  1                        0.82
# 344             1        0                  1                        0.80
#
#      gi_vs_xgi  expected_goal_involvements_per_90  total_points
# 391       1.89                               1.06            24
# 155       1.63                               0.73            21
# 115       0.98                               0.59            13
# 3         1.27                               0.37            14
# 136       0.30                               0.36            10
# 607      -0.21                               1.09             7
# 194       1.29                               0.49            12
# 431       0.90                               0.13             9
# 631       0.18                               0.42             8
# 344       0.20                               0.49            10
